# %% [markdown]
# <a href="https://colab.research.google.com/github/subhash505/NLP_code/blob/main/1_CV_Read_Image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opencv-python
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import cv2
import matplotlib.pyplot as plt
# To read image from disk, we use
# cv2.imread function, in below method,
img = cv2.imread("demo.jpg", cv2.IMREAD_COLOR)

plt.imshow(img)
img.shape
# Out:
# (464, 612, 3)

# %%
import numpy as np
import matplotlib.pyplot as plt
img=cv2.imread("demo.jpg")

# Converting BGR color to RGB color format
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

#Displaying image using plt.imshow() method
plt.imshow(img)
